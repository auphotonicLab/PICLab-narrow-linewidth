# %%
import O365

# %%
from O365 import Account
import os
from datetime import datetime, timedelta

def authenticate_outlook():
    """
    Authenticate with Microsoft 365 using client credentials.
    Returns an authenticated account object.
    """
    # You need to register your application in Azure AD and get these credentials
    client_id = "YOUR_CLIENT_ID"
    client_secret = "YOUR_CLIENT_SECRET"
    
    # Create an account object
    account = Account((client_id, client_secret))
    
    # Authenticate
    if account.authenticate():
        print("Authentication successful!")
        return account
    else:
        print("Authentication failed!")
        return None

def read_emails_from_folder(account, folder_name, days_back=7):
    """
    Read emails from a specific folder.
    
    Args:
        account: Authenticated O365 account object
        folder_name: Name of the folder to read from
        days_back: Number of days to look back for emails
    """
    # Get the mailbox
    mailbox = account.mailbox()
    
    # Get the folder
    folder = mailbox.get_folder(folder_name=folder_name)
    
    if folder is None:
        print(f"Folder '{folder_name}' not found!")
        return
    
    # Calculate the date to filter from
    date_from = datetime.now() - timedelta(days=days_back)
    
    # Get messages from the folder
    messages = folder.get_messages(
        query=f"receivedDateTime ge {date_from.strftime('%Y-%m-%d')}",
        limit=50  # Limit the number of messages to retrieve
    )
    
    # Process each message
    for message in messages:
        print(f"\nSubject: {message.subject}")
        print(f"From: {message.sender}")
        print(f"Received: {message.received}")
        print(f"Body: {message.body_preview[:200]}...")  # Show first 200 characters of body

def main():
    # Authenticate
    account = authenticate_outlook()
    
    if account:
        # Specify the folder name you want to read from
        folder_name = "Inbox"  # Change this to your desired folder name
        
        # Read emails from the specified folder
        read_emails_from_folder(account, folder_name)

if __name__ == "__main__":
    main()

# %%
from O365 import Account
import os
from datetime import datetime, timedelta

def authenticate_outlook():
    """
    Authenticate with Microsoft 365 using interactive authentication.
    Returns an authenticated account object.
    """
    # Create an account object with your email
    account = Account(credentials=None)  # No credentials needed for interactive auth
    
    # Authenticate - this will open a browser window for you to log in
    if account.authenticate(scopes=['basic', 'message_all']):
        print("Authentication successful!")
        return account
    else:
        print("Authentication failed!")
        return None

def read_emails_from_folder(account, folder_name, days_back=7):
    """
    Read emails from a specific folder.
    
    Args:
        account: Authenticated O365 account object
        folder_name: Name of the folder to read from
        days_back: Number of days to look back for emails
    """
    # Get the mailbox
    mailbox = account.mailbox()
    
    # Get the folder
    folder = mailbox.get_folder(folder_name=folder_name)
    
    if folder is None:
        print(f"Folder '{folder_name}' not found!")
        return
    
    # Calculate the date to filter from
    date_from = datetime.now() - timedelta(days=days_back)
    
    # Get messages from the folder
    messages = folder.get_messages(
        query=f"receivedDateTime ge {date_from.strftime('%Y-%m-%d')}",
        limit=50  # Limit the number of messages to retrieve
    )
    
    # Process each message
    for message in messages:
        print(f"\nSubject: {message.subject}")
        print(f"From: {message.sender}")
        print(f"Received: {message.received}")
        print(f"Body: {message.body_preview[:200]}...")  # Show first 200 characters of body

def main():
    # Authenticate
    account = authenticate_outlook()
    
    if account:
        # Specify the folder name you want to read from
        folder_name = "Inbox"  # Change this to your desired folder name
        
        # Read emails from the specified folder
        read_emails_from_folder(account, folder_name)

if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 68
#      65         read_emails_from_folder(account, folder_name)
#      67 if __name__ == "__main__":
# ---> 68     main()
#
# Cell In[3], line 58, in main()
#      56 def main():
#      57     # Authenticate
# ---> 58     account = authenticate_outlook()
#      60     if account:
#      61         # Specify the folder name you want to read from
#      62         folder_name = "Inbox"  # Change this to your desired folder name
#
# Cell In[3], line 11, in authenticate_outlook()
#       6 """
#       7 Authenticate with Microsoft 365 using interactive authentication.
#       8 Returns an authenticated account object.
#       9 """
#      10 # Create an account object with your email
# ---> 11 account = Account(credentials=None)  # No credentials needed for interactive auth
#      13 # Authenticate - this will open a browser window for you to log in
#      14 if account.authenticate(scopes=['basic', 'message_all']):
#
# File c:\Users\au617810\.conda\envs\conda_env\Lib\site-packages\O365\account.py:60, in Account.__init__(self, credentials, username, protocol, main_resource, **kwargs)
#      56         main_resource = ''
#      58 kwargs['username'] = username
# ---> 60 self.con = self.connection_constructor(credentials, **kwargs)
#      61 #: The resource in use for the account. |br| **Type:** str
#      62 self.main_resource: str = main_resource or self.protocol.default_resource
#
# File c:\Users\au617810\.conda\envs\conda_env\Lib\site-packages\O365\connection.py:457, in Connection.__init__(self, credentials, proxy_server, proxy_port, proxy_username, proxy_password, proxy_http_only, requests_delay, raise_http_errors, request_retries, token_backend, tenant_id, auth_flow_type, username, password, timeout, json_encoder, verify_ssl, default_headers, store_token_after_refresh, **kwargs)
#     451 else:
#     452     if (
#     453         not isinstance(credentials, tuple)
#     454         or len(credentials) != 2
#     455         or (not credentials[0] and not credentials[1])
#     456     ):
# --> 457         raise ValueError("Provide valid auth credentials")
#     459 self._auth_flow_type = (
#     460     auth_flow_type  # 'authorization', 'credentials', 'password', or 'public'
#     461 )
#     462 if auth_flow_type in ("credentials", "password") and tenant_id == "common":
#
# ValueError: Provide valid auth credentials

# %%
from O365 import Account
import os
from datetime import datetime, timedelta

def authenticate_outlook():
    """
    Authenticate with Microsoft 365 using email and password.
    Returns an authenticated account object.
    """
    # Create an account object with your email
    account = Account(credentials=('surrow@ece.au.dk', ''))
    
    # Authenticate
    if account.authenticate():
        print("Authentication successful!")
        return account
    else:
        print("Authentication failed!")
        return None

def read_emails_from_folder(account, folder_name, days_back=7):
    """
    Read emails from a specific folder.
    
    Args:
        account: Authenticated O365 account object
        folder_name: Name of the folder to read from
        days_back: Number of days to look back for emails
    """
    # Get the mailbox
    mailbox = account.mailbox()
    
    # Get the folder
    folder = mailbox.get_folder(folder_name=folder_name)
    
    if folder is None:
        print(f"Folder '{folder_name}' not found!")
        return
    
    # Calculate the date to filter from
    date_from = datetime.now() - timedelta(days=days_back)
    
    # Get messages from the folder
    messages = folder.get_messages(
        query=f"receivedDateTime ge {date_from.strftime('%Y-%m-%d')}",
        limit=50  # Limit the number of messages to retrieve
    )
    
    # Process each message
    for message in messages:
        print(f"\nSubject: {message.subject}")
        print(f"From: {message.sender}")
        print(f"Received: {message.received}")
        print(f"Body: {message.body_preview[:200]}...")  # Show first 200 characters of body

def main():
    # Authenticate
    account = authenticate_outlook()
    
    if account:
        # Specify the folder name you want to read from
        folder_name = "Inbox"  # Change this to your desired folder name
        
        # Read emails from the specified folder
        read_emails_from_folder(account, folder_name)

if __name__ == "__main__":
    main()
# Out:
# Visit the following url to give consent:
# https://login.microsoftonline.com/common/oauth2/v2.0/authorize?client_id=surrow%40ece.au.dk&response_type=code&redirect_uri=https%3A%2F%2Flogin.microsoftonline.com%2Fcommon%2Foauth2%2Fnativeclient&scope=https%3A%2F%2Fgraph.microsoft.com%2FCalendars.Read+https%3A%2F%2Fgraph.microsoft.com%2FCalendars.Read.Shared+https%3A%2F%2Fgraph.microsoft.com%2FCalendars.ReadWrite+https%3A%2F%2Fgraph.microsoft.com%2FCalendars.ReadWrite.Shared+https%3A%2F%2Fgraph.microsoft.com%2FContacts.Read+https%3A%2F%2Fgraph.microsoft.com%2FContacts.Read.Shared+https%3A%2F%2Fgraph.microsoft.com%2FContacts.ReadWrite+https%3A%2F%2Fgraph.microsoft.com%2FContacts.ReadWrite.Shared+https%3A%2F%2Fgraph.microsoft.com%2FFiles.Read.All+https%3A%2F%2Fgraph.microsoft.com%2FFiles.ReadWrite.All+https%3A%2F%2Fgraph.microsoft.com%2FMail.Read+https%3A%2F%2Fgraph.microsoft.com%2FMail.Read.Shared+https%3A%2F%2Fgraph.microsoft.com%2FMail.ReadWrite+https%3A%2F%2Fgraph.microsoft.com%2FMail.ReadWrite.Shared+https%3A%2F%2Fgraph.microsoft.com%2FMail.Send+https%3A%2F%2Fgraph.microsoft.com%2FMail.Send.Shared+https%3A%2F%2Fgraph.microsoft.com%2FMailboxSettings.ReadWrite+https%3A%2F%2Fgraph.microsoft.com%2FPresence.Read+https%3A%2F%2Fgraph.microsoft.com%2FSites.Read.All+https%3A%2F%2Fgraph.microsoft.com%2FSites.ReadWrite.All+https%3A%2F%2Fgraph.microsoft.com%2FTasks.Read+https%3A%2F%2Fgraph.microsoft.com%2FTasks.ReadWrite+https%3A%2F%2Fgraph.microsoft.com%2FUser.Read+https%3A%2F%2Fgraph.microsoft.com%2FUser.ReadBasic.All+offline_access+openid+profile&state=jdmWLzKFxRiHhvVY&code_challenge=U26R8R06Hxcu0RXLDL33mi5ZFf3sw89wHs8ANUae_iA&code_challenge_method=S256&nonce=6c87eab2c7e26ff3c8bede6ec768561aa79591a5ae749a88ba20bdd3c7537ca2&client_info=1
