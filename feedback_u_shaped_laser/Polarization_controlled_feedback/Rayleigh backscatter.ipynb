# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import re
import pandas as pd
# import scipy.signal as signal

# %%
path_on = r"O:\Tech_Photonics\Projects\Narrow Linewidth\MFB Chips\Chip 3 Feedback measurements\Rayleigh backscatter\Backscatter_on.csv"
path_off = r"O:\Tech_Photonics\Projects\Narrow Linewidth\MFB Chips\Chip 3 Feedback measurements\Rayleigh backscatter\Backscatter_off.csv"


data_on = pd.read_csv(path_on,skiprows=4,skipfooter=0,engine='python',delimiter=';')
data_off = pd.read_csv(path_off,skiprows=4,skipfooter=0,engine='python',delimiter=';')

# %%
data_off
# Out:
#        Date (MM/dd/yyyy)   Time of day (hh:mm:ss.fff)   PowerdBm(dBm)
# 0               1/23/2025                15:17:12.675         -53.597
# 1               1/23/2025                15:17:12.679         -53.587
# 2               1/23/2025                15:17:12.683         -53.596
# 3               1/23/2025                15:17:12.687         -53.618
# 4               1/23/2025                15:17:12.691         -53.597
# ...                   ...                         ...             ...
# 12125                Mean                 -52.359 dBm             NaN
# 12126  Standard Deviation                     --- dBm             NaN
# 12127               Ratio                       5.031             NaN
# 12128             Samples                       12122             NaN
# 12129        Elapsed Time                00:00:59:997             NaN
#
# [12130 rows x 3 columns]

# %%
# time_off = data_off[' Time of day (hh:mm:ss.fff)']- data_off[' Time of day (hh:mm:ss.fff)'][0]
plt.plot(data_off[' PowerdBm(dBm)'],label='off')
plt.plot(data_on[' PowerdBm(dBm)'],label='on')
plt.legend()

# %%
data_on
# Out:
#        Date (MM/dd/yyyy)   Time of day (hh:mm:ss.fff)   PowerdBm(dBm)
# 0               1/23/2025                15:14:24.766         -49.476
# 1               1/23/2025                15:14:24.769         -49.470
# 2               1/23/2025                15:14:24.773         -49.469
# 3               1/23/2025                15:14:24.776         -49.471
# 4               1/23/2025                15:14:24.779         -49.464
# ...                   ...                         ...             ...
# 12030                Mean                 -50.726 dBm             NaN
# 12031  Standard Deviation                     --- dBm             NaN
# 12032               Ratio                       7.554             NaN
# 12033             Samples                       12027             NaN
# 12034        Elapsed Time                00:00:59:998             NaN
#
# [12035 rows x 3 columns]
