# %%
from Siglent_communication import SiglentSDS800XHD

# %%
scope = SiglentSDS800XHD.connect_usb()
print("LAN type:  ", scope.query(":SYSTem:COMMunicate:LAN:TYPE?"))
print("IP address:", scope.query(":SYSTem:COMMunicate:LAN:IPADdress?"))
print("Subnet:    ", scope.query(":SYSTem:COMMunicate:LAN:SMASk?"))
print("MAC:       ", scope.query(":SYSTem:COMMunicate:LAN:MAC?"))
# Out:
# ---------------------------------------------------------------------------
# ScopeConnectionError                      Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 scope = SiglentSDS800XHD.connect_usb()
#       2 print("LAN type:  ", scope.query(":SYSTem:COMMunicate:LAN:TYPE?"))
#       3 print("IP address:", scope.query(":SYSTem:COMMunicate:LAN:IPADdress?"))
#       4 print("Subnet:    ", scope.query(":SYSTem:COMMunicate:LAN:SMASk?"))
#
# File c:\Users\au617810\OneDrive - Aarhus universitet\Videnskabelig assistent\PICLab_narrow_linewidth\QTLab\Siglent_communication.py:207, in SiglentSDS800XHD.connect_usb(cls, visa_resource)
#     205     candidates = [r for r in rm.list_resources() if r.startswith("USB")]
#     206     if not candidates:
# --> 207         raise ScopeConnectionError(
#     208             f"No USB VISA instruments found. Seen: {rm.list_resources()}"
#     209         )
#     210     visa_resource = candidates[0]
# ...
